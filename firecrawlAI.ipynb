# %%
# %pip install firecrawl-py
# %pip install python-dotenv
# Out:
# Requirement already satisfied: firecrawl-py in c:\users\hrahe\anaconda\lib\site-packages (1.10.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: nest-asyncio in c:\users\hrahe\anaconda\lib\site-packages (from firecrawl-py) (1.5.6)
# Requirement already satisfied: python-dotenv in c:\users\hrahe\anaconda\lib\site-packages (from firecrawl-py) (1.0.1)
# Requirement already satisfied: pydantic>=2.10.3 in c:\users\hrahe\anaconda\lib\site-packages (from firecrawl-py) (2.10.5)
# Requirement already satisfied: requests in c:\users\hrahe\anaconda\lib\site-packages (from firecrawl-py) (2.28.1)
# Requirement already satisfied: websockets in c:\users\hrahe\anaconda\lib\site-packages (from firecrawl-py) (14.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hrahe\anaconda\lib\site-packages (from pydantic>=2.10.3->firecrawl-py) (0.6.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\hrahe\anaconda\lib\site-packages (from pydantic>=2.10.3->firecrawl-py) (4.12.2)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\hrahe\anaconda\lib\site-packages (from pydantic>=2.10.3->firecrawl-py) (2.27.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hrahe\anaconda\lib\site-packages (from requests->firecrawl-py) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hrahe\anaconda\lib\site-packages (from requests->firecrawl-py) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\hrahe\anaconda\lib\site-packages (from requests->firecrawl-py) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hrahe\anaconda\lib\site-packages (from requests->firecrawl-py) (1.26.14)
# Requirement already satisfied: python-dotenv in c:\users\hrahe\anaconda\lib\site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## API KEY

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("FIRECRAWL_API_KEY")

# %% [markdown]
# ## Scrape the links of career/join us page from given url

# %%
from firecrawl import FirecrawlApp
from pydantic import BaseModel, Field


def get_career_links(url: str) -> list:
    """
    Extracts career-related links from a given URL using Firecrawl.

    Args:
        url (str): The URL of the website to extract links from.
        api_key (str): Your Firecrawl API key.

    Returns:
        list: A list of career-related links found on the page.
    """
    app = FirecrawlApp(api_key)

    response = app.scrape_url(url=url, params={
        'formats': ['links'],
        'onlyMainContent': False,
        'actions': [
            {
                "type": "wait",
                "milliseconds": 2,
            }
        ],
    })

    keywords = ["careers", "career", "job", "jobs","join"]
    career_links = []
    if 'links' in response:
        for link in response['links']:
            if any(keyword in link.lower() for keyword in keywords):
                career_links.append(link)
    else:
        print("The 'links' key was not found in the response.")

    return career_links


def add_wildcard_to_links(links: list) -> list:
    """
    Adds "/*" to the end of each URL in a list.

    Args:
        links (list): A list of URLs.

    Returns:
        list: A list of URLs with "/*" appended.
    """
    return [link + "/*" if not link.endswith("/*") else link for link in links]


# Example usage:
url = "https://www.amazon.com/"

career_links = get_career_links(url)

# Add wildcard and print updated links
updated_links = add_wildcard_to_links(career_links)

# %% [markdown]
# ##  Extract job listings in json

# %%
from firecrawl import FirecrawlApp
from pydantic import BaseModel, Field
from typing import List
import json

class PositionDept(BaseModel):
    position: str
    dept: str
    location: str
    description: str
    required_experience_in_years: str

class ExtractSchema(BaseModel):
    jobs: List[PositionDept]

def extract_job_postings(urls: List[str]) -> List[PositionDept]:
    """
    Extracts job postings from multiple URLs using Firecrawl and returns them.

    Args:
        urls (List[str]): A list of URLs to extract job postings from.
        api_key (str): Your Firecrawl API key.

    Returns:
        List[PositionDept]: A list of job postings.
    """
    app = FirecrawlApp(api_key=api_key)
    all_jobs = []

    for url in urls:
        data = app.extract([url], {
            'prompt': 'Extract Every Single job posting. For each job posting, find the open position they are hiring for and the department that position is for. Both of these will be in the website data. Also include location, description and required experience for that job if its data is available. eg {position:"Data Engineer", department:"Engineering"}',
            'schema': ExtractSchema.model_json_schema(),
        })

        if 'jobs' in data.get('data', {}) and data['data']['jobs']:
            all_jobs.extend(data['data']['jobs'])

    return all_jobs

def print_job_postings(jobs: List[PositionDept]):
    """
    Prints job postings.

    Args:
        jobs (List[PositionDept]): A list of job postings.
    """
    for job in jobs:
        print(json.dumps(job if isinstance(job, dict) else job.dict(), indent=4))
        print("-" * 20)

# Example usage:
urls = updated_links

jobs = extract_job_postings(urls)
print_job_postings(jobs)
# Out:
# {
#     "dept": "Operations",
#     "location": "Not specified",
#     "position": "Area Manager",
#     "description": "In this role, you will lead a team of hourly workforce and will be responsible for engaging your team during their shifts to maintain the highest levels of safety, quality, attendance, and performance. You will also play a key role in maintaining our customer expectations to ensure customer orders are delivered at the right time, to the right location.",
#     "required_experience_in_years": "2+"
# }
# --------------------
# {
#     "dept": "Fulfillment Center",
#     "location": "Not specified",
#     "position": "Area Manager",
#     "description": "Amazon is seeking Area Managers for our Fulfillment Centers (FCs). You will focus on safety, quality, customer experience, and productivity of your department. Responsibilities include reviewing work forecasts, partnering with other Area Managers, supporting safety programs, and leading process improvement initiatives.",
#     "required_experience_in_years": "2+"
# }
# --------------------
# {
#     "dept": "Fulfillment Centers",
#     "location": "AMD2",
#     "position": "Area Manager",
#     "description": "Amazon is seeking Area Managers for our Fulfillment Centers (FCs). Four key areas that you\u2019ll always focus on are the safety, quality, customer experience, and productivity of your department. Responsibilities include reviewing work forecasts, partnering with other Area Managers, supporting safety programs, and leading process improvement initiatives.",
#     "required_experience_in_years": "2+"
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "Tracy, CA",
#     "position": "Area Manager II",
#     "description": "In this role, you will lead a team of hourly workforce and will be responsible for engaging your team during their shifts to maintain the highest levels of safety, quality, attendance, and performance. You will also play a key role in maintaining our customer expectations to ensure customer orders are delivered at the right time, to the right location.",
#     "required_experience_in_years": "2+"
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "Not specified",
#     "position": "Area Manager, Outbound",
#     "description": "Amazon is seeking an Area Manager for our facility. You and your team of warehouse associates are responsible for ensuring that Amazon customers receive their orders accurately and on time. You are responsible for ensuring that your team members are properly trained and supported, addressing their needs so they can focus on delivering exceptional results.",
#     "required_experience_in_years": "Not specified"
# }
# --------------------
# {
#     "dept": "Rapid and Rural Logistics (R2L)",
#     "location": "Not specified",
#     "position": "Area Manager, RSR",
#     "description": "In this role, you will lead a team of hourly employees and will be responsible for engaging your team during their shifts to maintain the highest levels of safety, quality, attendance, and performance. You will also play a key part in maintaining our customer expectations to ensure customer orders are delivered at the right time, to the right location.",
#     "required_experience_in_years": "2+"
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "Little Rock, AR",
#     "position": "Area Manager II",
#     "description": "In this role, you will lead a team of hourly workforce and will be responsible for engaging your team during their shifts to maintain the highest levels of safety, quality, attendance, and performance. You will also play a key role in maintaining our customer expectations to ensure customer orders are delivered at the right time, to the right location.",
#     "required_experience_in_years": "2+"
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "Not specified",
#     "position": "Seasonal Process Assistant",
#     "description": "Support and work in the department as required, helping support daily management of department duties, including allocating labor, leading meetings, assigning job duties, and communicating with internal and external suppliers. Providing vacation coverage for Area Managers, tracking and reporting of ATS/labor hours, assisting the floor as an associate resource, training associates and verifying SOP compliance, ensuring successful area performance, participating in Operational Excellence initiatives, and addressing safety hazards.",
#     "required_experience_in_years": "Not specified"
# }
# --------------------
# {
#     "dept": "Amazon Web Services",
#     "location": "Columbus, OH",
#     "position": "Logistics Specialist",
#     "description": "Amazon is seeking an adventurous logistics professional for our Amazon Web Services Team in the Columbus, OH area. This position requires that the candidate selected be a US Citizen and must currently possess and maintain an active TS/SCI security clearance. Logistics Specialists monitor inventory levels to ensure that proper stock levels are maintained to support build and repair activities in our warehouse and data centers. They process inbound and outbound shipments, verify inventory, conduct cycle counts, manage an Inventory Management System and own chain-of-custody processes for Data Center Technicians and Engineers. They will also be responsible for transporting parts between different locations operating sprinter vans, trucks, or various powered equipment (i.e forklift or electric pallet jack).",
#     "required_experience_in_years": "1"
# }
# --------------------
# {
#     "dept": "Workplace Design & Construction",
#     "location": "Seattle, WA or Arlington, VA",
#     "position": "Design Program Manager III",
#     "description": "The Global Design team is looking for a creative, innovative, results-oriented Design Manager responsible for the design of post-occupancy tenant improvement projects in the Americas (AMER) portfolio. This role will oversee and manage the design of post-occupancy tenant improvement projects, collaborating with various teams to improve workplace design.",
#     "required_experience_in_years": "5+"
# }
# --------------------
# {
#     "dept": "Customer Engagement Technology",
#     "location": "Not specified",
#     "position": "Software Development Engineer",
#     "description": "Amazon.com is broadly recognized as #1 in Customer Service in the US and abroad. At Amazon we drive innovation and customer obsession into everything we do, and this is especially true in the Customer Engagement Technologies (CET) department. CET owns the technology to support and enhance our Customer Service Operations network through our Self Service and Automation features, CRM, contact center infrastructure, and various client applications.",
#     "required_experience_in_years": "3+"
# }
# --------------------
# {
#     "dept": "Central Flow - Central Ops",
#     "location": "Tempe, AZ & Nashville, TN",
#     "position": "2025 Central Flow Lead",
#     "description": "This is a corporate and office-based position. This is a full-time, entry level position. Amazon is looking for recent and upcoming graduates with high-potential to join our Central Flow team. Amazon North American Customer Fulfillment (NACF) Planning and Execution Team (PLEX) is a central part of Amazon and at the heart of our supply chain processes. The Central Flow team focuses on operational execution, risk mitigation, and best practices to deliver for our customers.",
#     "required_experience_in_years": "0-2"
# }
# --------------------
# {
#     "dept": "Data and Machine Learning",
#     "location": "US Federal",
#     "position": "Machine Learning Engineer",
#     "description": "Are you looking to work at the forefront of Machine Learning and AI? Would you be excited to apply state-of-the-art Generative AI algorithms to solve real world problems with significant impact? Amazon Web Services (AWS) Professional Services (ProServe) is looking for Machine Learning Engineers who like helping U.S. Federal agencies implement innovative cloud computing solutions and solve technical problems using state-of-the-art language models in the cloud.",
#     "required_experience_in_years": "3+"
# }
# --------------------
# {
#     "dept": "Customer Engagement Technology",
#     "location": "Not specified",
#     "position": "Senior Software Development Engineer",
#     "description": "Amazon.com is broadly recognized as a leader in providing exceptional Customer Service globally. At Amazon, we are driven by innovation and customer obsession, which is deeply ingrained in everything we do, especially in the Customer Engagement Technology (CET) department. Leveraging conversational Artificial Intelligence (AI) and machine learning (ML) technology, we strive to predict and resolve customer issues through self-service and automation solutions.",
#     "required_experience_in_years": "5+"
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "AR, LA, MS, AL, GA",
#     "position": "Area Manager 2025",
#     "description": "This is a full-time, entry level position located within one of Amazon\u2019s fulfillment centers, sort centers, delivery stations or other operations buildings. Amazon is seeking customer focused individuals to lead a team of hourly employees across our cutting-edge Operations network!",
#     "required_experience_in_years": "0"
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "SD, NE, KS, MO, IA",
#     "position": "Area Manager 2025",
#     "description": "This is a full-time, entry level position located within one of Amazon\u2019s fulfillment centers, sort centers, delivery stations or other operations buildings. Amazon is seeking customer focused individuals to lead a team of hourly employees across our cutting-edge Operations network!",
#     "required_experience_in_years": "0"
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "NV, AZ, CO, UT",
#     "position": "Area Manager 2025",
#     "description": "This is a full-time, entry level position located within one of Amazon\u2019s fulfillment centers, sort centers, delivery stations or other operations buildings. Amazon is seeking customer focused individuals to lead a team of hourly employees across our cutting-edge Operations network!",
#     "required_experience_in_years": "0"
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "Connecticut",
#     "position": "Area Manager 2025",
#     "description": "This is a full-time, entry level position located within one of Amazon\u2019s fulfillment centers, sort centers, delivery stations or other operations buildings. Amazon is seeking customer focused individuals to lead a team of hourly employees across our cutting-edge Operations network!",
#     "required_experience_in_years": "0"
# }
# --------------------
# {
#     "dept": "WWPS US Federal",
#     "location": "Not specified",
#     "position": "Application Developer, Data & Machine Learning",
#     "description": "Are you a developer who has hands-on experience with building cloud-native applications? Would you like to work with our customers to help them architect, develop and re-engineer applications to fully leverage the AWS Cloud?",
#     "required_experience_in_years": "5+"
# }
# --------------------
# {
#     "dept": "US Federal Data and Machine Learning",
#     "location": "Not specified",
#     "position": "Senior Data Architect",
#     "description": "Do you like helping U.S. Federal agencies implement innovative data solutions? Would you like to do this using the latest cloud computing technologies? Do you have a knack for helping these groups understand data architectures and integration approaches, and the consultative and leadership skills to launch a project on a trajectory to success?",
#     "required_experience_in_years": "5+ years of database experience, 3+ years of cloud based solution experience, 7+ years of project management experience."
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "Vacaville, CA",
#     "position": "Area Manager II",
#     "description": "In this role, you will lead a team of hourly workforce and will be responsible for engaging your team during their shifts to maintain the highest levels of safety, quality, attendance, and performance. You will also play a key role in maintaining our customer expectations to ensure customer orders are delivered at the right time, to the right location.",
#     "required_experience_in_years": "2+"
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "Kent, WA",
#     "position": "Operations Manager",
#     "description": "In this role, you will lead and develop a team of salaried and hourly talent. You will be responsible for engaging your team during their shifts to maintain the highest levels of safety, quality, attendance, and performance.",
#     "required_experience_in_years": "3+"
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "Not specified",
#     "position": "Lead Fulfillment Associate",
#     "description": "The Amazon operations team is looking for Lead Fulfillment Associates with a strong record of achieving results to join the expanding team supporting operations leaders and associates in delivering strong operations results within our fulfillment centers. Lead Fulfillment Associates hold various roles within the Fulfillment Center including, but not limited to: Trainer, Process Assistant and Shipping Clerk. All role types will include performing production duties as needed: pick/pack orders, receive/stow product, ensure inventory accuracy, and unload/load trucks. Lead Fulfillment Associates will also be responsible for communicating instructions to other associates, motivating them and keeping their work areas safe.",
#     "required_experience_in_years": "1+"
# }
# --------------------
# {
#     "dept": "Logistics for Good",
#     "location": "Bellevue, WA",
#     "position": "Program Manager, Logistics for Good",
#     "description": "The Logistics for Good is seeking an experienced Program Manager for our Food Security and Natural Disaster Recovery initiatives. Logistics for Good's mission is to utilize Amazon's transportation and logistics resources for social impact. We strive for solutions that benefit customers experiencing food insecurity and natural disasters. As the leader in this role, you will collaborate closely with internal transportation and logistics teams, as well as various departments across Amazon. Additionally, you may engage externally with community leaders, governmental bodies, and nonprofit organizations to drive meaningful change.",
#     "required_experience_in_years": "3+"
# }
# --------------------
# {
#     "dept": "People eXperience and Technology",
#     "location": "Not specified",
#     "position": "Executive Assistant",
#     "description": "Amazon is seeking a multitasking and self-motivated individual to support two Directors in the Hiring Software Delivery (HSD). This exciting role requires attention to detail; the ability to meet tight deadlines, great organizational skills, and the ability to juggle multiple critical requests.",
#     "required_experience_in_years": "2+ years of senior level leadership support, or 1+ years of Amazon experience"
# }
# --------------------
# {
#     "dept": "Business Operations, Customer Logistics Security (CLS)",
#     "location": "Not specified",
#     "position": "Sr Program Manager",
#     "description": "The Senior Program Manager of CLS Business Operations will operate as a key resource, working in tandem with the team\u2019s leadership in providing support across sub-teams and Business Security Teams (BSTs) to help strategically operate and develop the organization. This role will support the development and delivery of short and long-term business and financial goals.",
#     "required_experience_in_years": "5+"
# }
# --------------------
# {
#     "dept": "Worldwide Operations",
#     "location": "Tepotzotlan, MEX",
#     "position": "ICQA Area Manager Jr.",
#     "description": "Supervise safety, quality, customer experience, and productivity of our department. This entry-level role will work closely with Area Managers, process owners and business leaders to balance workload ensuring that the organization is operating on balanced and efficient shift while meeting all of your goals.",
#     "required_experience_in_years": "1+"
# }
# --------------------
# {
#     "dept": "Customer Engagement Technology",
#     "location": "Not specified",
#     "position": "Software Development Manager",
#     "description": "Amazon.com is broadly recognized as #1 in Customer Service in the US and abroad. At Amazon we drive innovation and customer obsession into everything we do, and this is especially true in the Customer Engagement Technology (CET) department. CET owns the technology to support and enhance our Customer Service Operations network through our Self Service and Automation features, CRM, contact center infrastructure, and various client applications. We focus on robust architecture, world class UX, and leverage our Big Data to drive insights and solutions through a myriad of applications.",
#     "required_experience_in_years": "7+ years of working directly within engineering teams experience, 3+ years of engineering team management experience."
# }
# --------------------
# {
#     "dept": "Global Tax Services",
#     "location": "Not specified",
#     "position": "Senior Program Manager",
#     "description": "The Amazon Tax department is a fast-paced, team-focused, dynamic environment. Amazon Global Tax Services is seeking a Sr. Program Manager with experience in process improvement, requirements gathering, and cross-functional leadership. Successful candidates will have strong Program Management skills, experience working with Technical teams, and some Finance (specifically Tax and/or Accounting) familiarity.",
#     "required_experience_in_years": "5+"
# }
# --------------------
# {
#     "dept": "Trusted Order and Remediation Experiences",
#     "location": "Not specified",
#     "position": "Senior Risk Manager",
#     "description": "Amazon's Seller Performance Indicator (SPI) is one of our most important mechanisms to ensure customers receive perfect order experiences when shopping from Amazon's 2.3 million sellers and their billions of product offering. Our team ingests implicit and explicit inputs across product, fulfilment, and service quality, applying a scientific approach to form a holistic understanding of seller performance. This Risk Manager has global ownership over the risks associated with how we collect, moderate, and vend these signals.",
#     "required_experience_in_years": "6+"
# }
# --------------------
# {
#     "dept": "Amazon AI",
#     "location": "Not specified",
#     "position": "Applied Scientist",
#     "description": "Amazon AI is looking for an Applied Scientist to join our science team in the area of Multimodal Learning, Large Language Models, Natural Language Processing and Speech/Audio Representation Learning. Our organization develops the science that drives the cloud-based AI services of AWS. Our mission is to put the power of AI into the hands of every developer. We seek to advance the state of the art in machine learning to create services that delight our customers and meet real-world business needs. As an Applied Scientist you will partner with talented scientists and engineers to design, train, test, and deploy machine learning models. You will contribute to innovative features, improve our services based on customer requirements and help maintain a highly scalable data and model management infrastructure that supports cutting-edge research. You will be responsible for translating business and engineering requirements into deliverables and software products.",
#     "required_experience_in_years": "6+"
# }
# --------------------
# {
#     "dept": "Customer Service",
#     "location": "Not specified",
#     "position": "Delivery Station Customer Service Associate",
#     "description": "As a Delivery Station Customer Service Associate, you will help improve the customer experience by providing in station real-time, hands-on support to ensure our customers receive their packages on time, as promised. The role will also help connect customers with experts who can provide them the most accurate and up-to-date information about their packages.",
#     "required_experience_in_years": "Not specified"
# }
# --------------------
# {
#     "dept": "Amazon Vendor Services",
#     "location": "Seattle, WA",
#     "position": "Senior Customer Success Manager - Mandarin Speaking Required",
#     "description": "As a Senior Customer Success Manager with Amazon Vendor Services, you will work with Amazon\u2019s top vendor partners, influencing growth across their businesses on Amazon.com and improving end-customer experience. You will provide data driven strategic insights and ensure high operational standards.",
#     "required_experience_in_years": "3+"
# }
# --------------------
# {
#     "dept": "Amazon Music Search",
#     "location": "San Francisco, CA",
#     "position": "Mobile Software Engineer II",
#     "description": "Amazon Music is an immersive audio entertainment service that deepens connections between fans, artists, and creators. The Amazon Search Experience engineering team's vision is to provide a delightful experience to search, explore and discover content on Amazon Music. We build frontend and backend technology to enable a rich search experience across multiple clients, including mobile, web, FireTV and Big Screens.",
#     "required_experience_in_years": "2+"
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "Tracy, CA",
#     "position": "Operations Manager",
#     "description": "In this role, you will lead and develop a team of salaried and hourly talent. You will be responsible for engaging your team during their shifts to maintain the highest levels of safety, quality, attendance, and performance. Managers are expected to provide their team with the tools needed for success while driving improvements in productivity and efficiency through data-driven decisions and analytical problem-solving.",
#     "required_experience_in_years": "3+"
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "Thornton, CO",
#     "position": "Area Manager II",
#     "description": "In this role, you will lead a team of hourly workforce and will be responsible for engaging your team during their shifts to maintain the highest levels of safety, quality, attendance, and performance. You will also play a key role in maintaining our customer expectations to ensure customer orders are delivered at the right time, to the right location.",
#     "required_experience_in_years": "2+"
# }
# --------------------
# {
#     "dept": "Risk Management",
#     "location": "Nationwide",
#     "position": "2025 Risk Specialist FTE",
#     "description": "As a Risk Specialist at Amazon, you will focus on improving the success of the organization by diving deep into core areas of the company, partnering with Amazon\u2019s cutting-edge businesses to identify areas of risk, analyze data, and solve real world problems. Risk Specialists add value and help protect Amazon in all areas of the business.",
#     "required_experience_in_years": "0-2"
# }
# --------------------
# {
#     "dept": "Global Specialty Fulfillment",
#     "location": "Victoria, TX",
#     "position": "Site Leader",
#     "description": "In this role, you will play a key part in maintaining our customer expectations to ensure customer orders are delivered at the right time, to the right location. You will lead and develop a team of salaried and hourly talent. You will be responsible for engaging your team during their shifts to maintain the highest levels of safety, quality, attendance, and performance.",
#     "required_experience_in_years": "3+"
# }
# --------------------
# {
#     "dept": "Amazon Transportation Service (ATS)",
#     "location": "Not specified",
#     "position": "Operations Manager",
#     "description": "Operations is the beating heart of Amazon. This key part of our business makes sure we fulfill and dispatch orders efficiently so that our customers get their items on time. It\u2019s driven by Operations Managers who bring the team together to push excellence in safety, quality and productivity across our sites. At your site, you\u2019ll lead other managers and create the operational plan that helps your teams meet their targets. This role is all about driving operational excellence to create the Amazon of tomorrow.",
#     "required_experience_in_years": "Not specified"
# }
# --------------------
# {
#     "dept": "Pharmacy Operations",
#     "location": "Not specified",
#     "position": "Area Manager L5",
#     "description": "As a Team Lead you will play a key role in ensuring the pharmacy operations in an efficient manner to drive productivity and quality for our customers by managing a team of pharmacy technicians.",
#     "required_experience_in_years": "2+"
# }
# --------------------
# {
#     "dept": "Customer Fulfilment",
#     "location": "Not specified",
#     "position": "Area Manager",
#     "description": "As an Area Manager, you\u2019ll make sure your site is running as smoothly as it should so that we can meet customer demand. You will be leading a team that helps keep our operations safe, efficient, and of a high quality and taking on a number of projects across our network to drive productivity.",
#     "required_experience_in_years": "Not specified"
# }
# --------------------
# {
#     "dept": "People eXperience and Technology",
#     "location": "Not specified",
#     "position": "Human Resources Analyst",
#     "description": "The Sr HR Assistant is both a strategic and hands-on role that provides Human Resources support to the fulfillment center. The role is critical in executing our people initiatives, providing great internal customer support, and driving HR functional excellence and process improvement.",
#     "required_experience_in_years": "1+"
# }
# --------------------
# {
#     "dept": "People Experience and Technology (PXT)",
#     "location": "S\u00e3o Jo\u00e3o de Meriti - RJ",
#     "position": "HR Business Partner",
#     "description": "Responsible for the entire PXT agenda in an Amazon logistics warehouse, managing workforce mobilization, internal communication, employee engagement, leadership development, and labor relations issues.",
#     "required_experience_in_years": "Not specified"
# }
# --------------------
# {
#     "dept": "Inclusive Experience and Technology",
#     "location": "Not specified",
#     "position": "Executive Assistant",
#     "description": "The Inclusive Experience and Technology (IXT) organization is looking for an Executive Assistant who wants to work in a fast-paced, exciting, and growing organization. We are looking for someone to support the Vice President. This Executive Assistant will be responsible for handling confidential information and maintaining professionalism in dealing with senior executives. Role responsibilities include managing multiple complex calendars, planning and organizing events of all sizes, and coordinating domestic and international travel.",
#     "required_experience_in_years": "5+ years of senior level leadership support, or 3+ years of Amazon experience"
# }
# --------------------
# {
#     "dept": "Amazon Extra Large (AMXL)",
#     "location": "Not specified",
#     "position": "Logistics Scheduler",
#     "description": "As a Logistics Scheduler you will have the opportunity to create world-class customer experiences leveraging your innovation, team player and problem solving skills. This position involves working in a rotating three-shift system, which may include Saturdays, Sundays, night shifts and on-call duty. You will execute daily same day or next day forecasts, plan delivery routes, ensure targets and service deadlines are met, and communicate with various departments to facilitate the flow of information.",
#     "required_experience_in_years": "Relevant experience in an analytical tasks or projects, working with data."
# }
# --------------------
# {
#     "dept": "Customer Fulfillment",
#     "location": "Not specified",
#     "position": "Operations Manager",
#     "description": "We\u2019re seeking an experienced, Operations Manager to join our Customer Fulfillment team. You\u2019ll operate out of one of our dynamic Fulfillment Centers: these sit at the heart of Amazon\u2019s world-class, rapidly growing business. They\u2019re where we manage our fast-moving inventory; they\u2019re also where we developed our smart, industry-leading workflows. As an Operations Manager, you\u2019ll deliver inspiring, supportive leadership for the teams you manage. But at the same time, you don\u2019t shy away from rolling up your sleeves and getting involved whenever necessary. You\u2019ll be directly responsible for managing a team of Area Managers and their direct reports: meanwhile, you will report to the Senior Operations Manager of your Fulfillment Center. The quality of your leadership is key to success in this role: you\u2019ll motivate and inspire your teams to do their best work, while planning schedules and activities that balance their needs with that of the business. Another key aspect of your role will be to lead on numerous process improvement projects, with the aim of streamlining all activities, both for yourself and the team members you manage. The ideas, innovation and leaps out of the status quo that you come up with could very well be rolled out across the Amazon network: this immense opportunity is yours for the taking.",
#     "required_experience_in_years": "Not specified"
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "FAT2",
#     "position": "Area Manager",
#     "description": "In this role, you will lead a team of hourly workforce and will be responsible for engaging your team during their shifts to maintain the highest levels of safety, quality, attendance, and performance. You will also play a key role in maintaining our customer expectations to ensure customer orders are delivered at the right time, to the right location.",
#     "required_experience_in_years": "2+"
# }
# --------------------
# {
#     "dept": "Amazon Transportation",
#     "location": "Not specified",
#     "position": "Senior Program Manager",
#     "description": "Amazon is looking for a Senior Program Manager with a strong delivery record and proven project management experience to own strategic, tactical, cross-functional and technology projects and programs across multiple verticals. This role requires scoping and creating project plans, developing processes, coordinating and driving execution, and communicating to senior management on status, risks and process/product changes.",
#     "required_experience_in_years": "5+"
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "Not specified",
#     "position": "Area Manager",
#     "description": "As an Area Manager, you\u2019ll make sure your site is running as smoothly as it should so that we can meet customer demand. You will be leading a team that helps keep our operations safe, efficient, and of a high quality and taking on a number of projects across our network to drive productivity.",
#     "required_experience_in_years": "Not specified"
# }
# --------------------
# {
#     "dept": "Listing Services, Core Selling Partner Experience",
#     "location": "Not specified",
#     "position": "Business Analyst",
#     "description": "The Listing Services team, a part of the wider Core Selling Partner Experience division, is seeking a Business Analyst to support analytics and insights for its key initiatives. The BA will develop analytical solutions to solve problems, dive deep into defined business metrics, or support the development of new metrics, thus providing the team insights that will shape its direction and strategic vision.",
#     "required_experience_in_years": "3+"
# }
# --------------------
# {
#     "dept": "Human Resources",
#     "location": "Not specified",
#     "position": "HR Manager",
#     "description": "The HR Manager is an active member of the Operations HR team, driving and supporting cross-group initiatives. This role provides full cycle Human Resources support to the new Amazon Fulfillment Center, leading a team of 4 HR members and reporting to the Senior HR Manager Australia FCs. The position is critical in executing people initiatives, providing internal customer support, and driving HR functional excellence and process improvement.",
#     "required_experience_in_years": "5+"
# }
# --------------------
# {
#     "dept": "Prime Air",
#     "location": "Seattle, WA",
#     "position": "Supply Chain Analyst",
#     "description": "We are seeking a Supply Chain Manager to effectively drive enhancement of our Supply Chain Inventory, Shipping, Receiving and Transportation strategies. In this role, you will lead projects, own value-stream KPIs, and develop mechanisms for communicating status, risk, and business challenges.",
#     "required_experience_in_years": "3+ years of program or project management experience, 3+ years of working cross functionally with tech and non-tech teams experience, 3+ years of defining and implementing process improvement initiatives using data and metrics experience, 2+ years of supply chain experience."
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "Not specified",
#     "position": "Process Assistant, OTR",
#     "description": "In this role, you will lead and be responsible for supporting delivery associates through each step of the delivery process and tracking delivery metrics. You will also be responsible for training all delivery associates in safety, compliance, and the operation of the vehicle through all local, state, federal requirements.",
#     "required_experience_in_years": "1+"
# }
# --------------------
# {
#     "dept": "GREF",
#     "location": "Not specified",
#     "position": "Market Researcher",
#     "description": "This is a unique opportunity to help shape the workplace experience for Amazonians around the world. The Global Real Estate and Facilities (GREF) organization is responsible for creating the spaces that inspire Amazonians to make history. The globally diverse team manages Amazon\u2019s corporate offices in more than 60 countries. GREF provides real estate transactions expertise, business partnering, space and occupancy planning, design and construction, capital investment program management, facility maintenance, and operations all contributing to the employee experience and leveraging places and programs to enable culture to thrive at Amazon.",
#     "required_experience_in_years": "7+"
# }
# --------------------
# {
#     "dept": "Commerce",
#     "location": "Seattle, WA",
#     "position": "Software Engineer I",
#     "description": "As an engineer on the team, you will work alongside a highly engaged and collaborative team that works to design, build and maintain systems that scale to millions of concurrent users. You will help improve experiences for users and build new features to help creators recognize and reward their supporters.",
#     "required_experience_in_years": "Not specified"
# }
# --------------------
# {
#     "dept": "Amazon Vendor Services",
#     "location": "Seattle, WA",
#     "position": "Senior Customer Success Manager",
#     "description": "As a Senior Customer Success Manager with Amazon Vendor Services, you will work with Amazon\u2019s top vendor partners, influencing growth across their businesses on Amazon.com and improving end-customer experience. You will provide data driven strategic insights and ensure high operational standards.",
#     "required_experience_in_years": "4+"
# }
# --------------------
# {
#     "dept": "Customer Service Technology",
#     "location": "Not specified",
#     "position": "Business Intelligence Engineer",
#     "description": "Amazon seeks a Business Intelligence Engineer to help promote the adoption of Data-Backed Experimentation and Analytics in Customer Service. You will support an emerging charter to enable experimentation and self-service analytics within Amazon's worldwide Customer Service organization.",
#     "required_experience_in_years": "3+"
# }
# --------------------
# {
#     "dept": "Social Media",
#     "location": "San Francisco, CA",
#     "position": "Social Media Intern",
#     "description": "As a Social Media Intern, you will assist on Twitch\u2019s community engagement approach across our owned channels. You will be part of a small team that works with nearly every department at Twitch and will help coordinate calendar management with our agency partners. You\u2019ll work with the team to develop plans to achieve established goals, and improve processes to ensure our content pipeline with cross functional partners is strong and fluid.",
#     "required_experience_in_years": "N/A"
# }
# --------------------
# {
#     "dept": "Ads Security",
#     "location": "Not specified",
#     "position": "Security Engineer II",
#     "description": "The Ads Security organization at Amazon is dedicated to creating innovative technical solutions that detect, assess, and mitigate security risks within Amazon\u2019s Advertising businesses. Our vision is to accelerate the development velocity of the Advertising business by ensuring that our products are inherently secure. We are seeking a talented engineer to join our team, where you will have the opportunity to contribute to securing web applications and services critical to delivering exceptional customer and partner experiences at scale in Amazon Ads.",
#     "required_experience_in_years": "5+"
# }
# --------------------
# {
#     "dept": "Disability and Leave Service Team",
#     "location": "Prague, Czech Republic (or remote from Romania, Poland, Slovakia, and Czech Republic)",
#     "position": "Case Manager with French and English",
#     "description": "The DLS Case Manager provides case management for all types of leave of absence and disability life events. The DLS Case Manager is highly skilled in answering questions, understanding the employee\u2019s situation, applying the appropriate benefits, responding to changing circumstances and needs, and paves the way for a connected and trusted case management experience.",
#     "required_experience_in_years": "Not specified"
# }
# --------------------
# {
#     "dept": "AWS Infrastructure Services",
#     "location": "Not specified",
#     "position": "Logistics Specialist",
#     "description": "Logistics Specialists monitor inventory levels to ensure that proper stock levels are maintained to support build and repair activities. They receive parts, maintain inventory, and check-out parts as needed to Data center Technicians and Engineers. They will also be responsible for loading and unloading shipments and transporting parts between different locations.",
#     "required_experience_in_years": "1+"
# }
# --------------------
# {
#     "dept": "Alexa Shopping",
#     "location": "Bucharest",
#     "position": "ML Data Associate with Italian",
#     "description": "We are seeking a Data Associate for our annotation and data investigation operations team. This team plays a critical role in improving Alexa\u2019s natural language understanding (NLU) leading to improved customer experience quality metrics and positive business impact. The Data Associate should have a passion for data, efficiency, and accuracy and will work under the direction of Operations manager and Sr. Data Associates.",
#     "required_experience_in_years": "Not specified"
# }
# --------------------
# {
#     "dept": "Customer Engagement Technology",
#     "location": "Not specified",
#     "position": "Program Manager, Self Service & Automation",
#     "description": "Are you someone who cares about customer experience and wants to be involved in delivering innovative support experiences for customers of Amazon\u2019s products using Artificial Intelligence? Then we're looking for you! We are seeking a Program Manager to join the Customer Engagement Technology (CET) Team. You will be responsible for driving a high-visibility program of reducing customer service contacts that go to an agent through the expansion of our automated tools as well as through Artificial Intelligence (AI). You will own and execute a complex projects and programs that spans across the globe and multiple organizations within Amazon. You will be a thought leader and innovator within the organization.",
#     "required_experience_in_years": "3+"
# }
# --------------------
# {
#     "dept": "Central Technology Organization",
#     "location": "Not specified",
#     "position": "Executive Assistant",
#     "description": "As an Executive Assistant, you will work in a team environment, build effective working relationships inside and outside of the group, while keeping abreast of general business objectives, policies, standards, services, facilities, procedures and related information in order to maintain a comprehensive awareness of the organization. A high level of integrity and discretion in handling confidential information, and professionalism in dealing with leaders (at and outside Amazon) is important, as is the ability to be flexible and change direction seamlessly and handle multiple tasks at once. You will complete high volumes of tasks with minimal guidance or supervision while maintaining awareness of deadline sensitivity. As such, the candidate must be skilled at anticipating problems, creating contingency plans, managing multiple priorities, problem solving and organizing logistics. A successful candidate will want to take on varied and exciting new projects and also learn new skills. You will need to take effective action without having to know the total picture, and efficiently and proactively solve difficult or complex problems that affect people within the department or other related groups.",
#     "required_experience_in_years": "Not specified"
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "Not specified",
#     "position": "Team Lead",
#     "description": "Amazon.com, Inc. is a US-based multinational electronic commerce company headquartered in Seattle, Washington. At Amazon, we're working to be the most customer-centric company on earth. To get there, we need exceptionally talented, bright, and driven people. Four key areas that you\u2019ll always focus on are the safety, quality, customer experience, and productivity of your department. Responsibilities include reviewing work forecasts, partnering with Area Managers, supporting safety programs, and leading process improvement initiatives.",
#     "required_experience_in_years": "1+"
# }
# --------------------
# {
#     "dept": "Alexa Audio",
#     "location": "Not specified",
#     "position": "Data Analyst",
#     "description": "The Alexa Audio team at Amazon is looking for a highly motivated and talented candidate for the role of a Data Analyst. Proficiency in written and verbal English is a fundamental requirement for this position. The ideal candidate will be responsible for conducting quality audits, identifying defects, and using available tools to make corrections. The candidate is also expected to use human judgement to make decisions on behalf of our customers. Strong qualitative research, quantitative analysis, communication skills, attention to detail; and a commitment to excellence are the required skill sets for this role.",
#     "required_experience_in_years": "2+"
# }
# --------------------
# {
#     "dept": "Integrated Projects Quality (IPQ)",
#     "location": "Not specified",
#     "position": "Quality Control Engineer",
#     "description": "The Quality Control Engineer (QCE) plays an essential role in AWS Data Center Capacity Delivery\u2019s (DCCD) Integrated Project Quality (IPQ) program. This position is responsible for overseeing and executing quality assurance and control (QAQC) processes throughout the lifecycle of data center construction projects, ensuring that all work meets AWS's high standards for quality, safety, and performance.",
#     "required_experience_in_years": "5+"
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "MI, IN",
#     "position": "Area Manager 2025",
#     "description": "This is a full-time, entry level position located within one of Amazon\u2019s fulfillment centers, sort centers, delivery stations or other operations buildings. Amazon is seeking customer focused individuals to lead a team of hourly employees across our cutting-edge Operations network!",
#     "required_experience_in_years": "0"
# }
# --------------------
# {
#     "dept": "ProServe Variable WWPS",
#     "location": "Not specified",
#     "position": "Cloud Consultant",
#     "description": "Do you like helping the U.S. Department of Defense implement innovative cloud computing solutions and solve technical problems? Would you like to do this using the latest cloud computing technologies? Do you have a knack for helping these groups understand application architectures and integration approaches, and the consultative and leadership skills to launch a project on a trajectory to success?",
#     "required_experience_in_years": "3+"
# }
# --------------------
# {
#     "dept": "Worldwide Operations",
#     "location": "Not specified",
#     "position": "General Manager Assistant",
#     "description": "We are seeking an Administrative Assistant to support the General Manager and Fulfillment Center Operations team. The successful candidate will be highly organized, extremely detail oriented, self-motivated, able to handle confidential information, as well as a demonstrated ability to respond effectively to changing workloads and priorities. You must have the ability to communicate well and to manage multiple assignments and people simultaneously.",
#     "required_experience_in_years": "2+"
# }
# --------------------
# {
#     "dept": "AWS Infrastructure Services",
#     "location": "Aurora, CO",
#     "position": "Logistics Specialist",
#     "description": "AWS Infrastructure Services owns the design, planning, delivery, and operation of all AWS global infrastructure. In other words, we\u2019re the people who keep the cloud running. We support all AWS data centers and all of the servers, storage, networking, power, and cooling equipment that ensure our customers have continual access to the innovation they rely on.",
#     "required_experience_in_years": "2 years of logistics experience, preferably in a warehouse environment and minimum of 1 year experience driving box trucks up to 26\u2019 in length."
# }
# --------------------
# {
#     "dept": "Customer Service",
#     "location": "Not specified",
#     "position": "CS Delivery Station Liaison",
#     "description": "As a Delivery Station Customer Service Associate, you will help improve the customer experience by providing in station real-time, hands-on support to ensure our customers receive their packages on time, as promised. The role will also help connect customers with experts who can provide them the most accurate and up-to-date information about their packages.",
#     "required_experience_in_years": "Not specified"
# }
# --------------------
# {
#     "dept": "Delivery Experience Speed",
#     "location": "Bellevue, WA",
#     "position": "Data Engineer",
#     "description": "At Amazon, we are working to be the most Customer-centric company on earth. If you would like to help us build an excellent delivery experience, this is your chance to make history. The Worldwide Delivery Experience team continues to innovate with delivery speed initiatives for customers with the objective ensuring Amazon continues to own \u2018fast\u2019 in the minds of our customers. As a Data Engineer, you will need to review technical requirements, develop and enhance systems and pipelines supporting process optimization in reporting, planning, and controlling activities in EU Engineering Services, as well as integrate in-house infrastructure with partner systems.",
#     "required_experience_in_years": "3+"
# }
# --------------------
# {
#     "dept": "Operations",
#     "location": "Ohio",
#     "position": "Area Manager 2025",
#     "description": "This is a full-time, entry level position located within one of Amazon\u2019s fulfillment centers, sort centers, delivery stations or other operations buildings. Amazon is seeking customer focused individuals to lead a team of hourly employees across our cutting-edge Operations network!",
#     "required_experience_in_years": "0"
# }
# --------------------
# {
#     "dept": "Customer Engagement Technology",
#     "location": "Not specified",
#     "position": "Software Development Engineer",
#     "description": "Amazon.com is broadly recognized as a leader in providing exceptional Customer Service globally. At Amazon, we are driven by innovation and customer obsession, which is deeply ingrained in everything we do, especially in the Customer Engagement Technology (CET) department. Leveraging conversational Artificial Intelligence (AI) and machine learning (ML) technology, we strive to predict and resolve customer issues through self-service and automation solutions.",
#     "required_experience_in_years": "3+"
# }
# --------------------
# {
#     "dept": "AWS Infrastructure Services",
#     "location": "Not specified",
#     "position": "Infrastructure Technical Program Manager",
#     "description": "AWS Infrastructure Services owns the design, planning, delivery, and operation of all AWS global infrastructure. In this position you will be responsible for prioritization, scheduling and execution of network changes and upgrades across Amazon Data Centers. You will manage our cross-functional projects, which require working with multiple AWS internal departments and groups including network operations, network engineering staff and internal project management teams, as well as external vendors.",
#     "required_experience_in_years": "5+"
# }
# --------------------
# {
#     "dept": "Helper",
#     "location": "139 W Jericho Turnpike, Huntington Station, NY 11746, USA",
#     "position": "Amazon DSP Driver Helper",
#     "description": "Starting pay $17.00/hour+",
#     "required_experience_in_years": ""
# }
# --------------------
# {
#     "dept": "",
#     "location": "139 W Jericho Turnpike, Huntington Station, NY 11746, USA",
#     "position": "Amazon DSP Box Truck/DOT Delivery Driver",
#     "description": "Starting pay $23.50/hour+",
#     "required_experience_in_years": ""
# }
# --------------------
# {
#     "dept": "",
#     "location": "10355 S Carlisle St, Terre Haute, IN 47802, USA",
#     "position": "Amazon DSP NON\u2013DOT Delivery Driver",
#     "description": "Starting pay $21.75/hour+",
#     "required_experience_in_years": ""
# }
# --------------------
# {
#     "dept": "",
#     "location": "4400 S Washington Ave, Mason City, IA 50401, USA",
#     "position": "Amazon DSP NON\u2013DOT Delivery Driver",
#     "description": "Starting pay $20.25/hour+",
#     "required_experience_in_years": ""
# }
# --------------------
# {
#     "dept": "",
#     "location": "270 Richards St, Brooklyn, NY 11231, USA",
#     "position": "Amazon DSP Delivery Driver",
#     "description": "Starting pay $22.75/hour+",
#     "required_experience_in_years": ""
# }
# --------------------
# {
#     "dept": "",
#     "location": "45 Lau Pkwy, Clayton, OH 45315, USA",
#     "position": "Amazon DSP Box Truck/DOT Delivery Driver",
#     "description": "Starting pay $21.75/hour+",
#     "required_experience_in_years": ""
# }
# --------------------

# %%
from typing import List, Dict

def analyze_jobs(jobs: List[Dict]):
    """
    Analyzes job postings to count total jobs, jobs per department, and jobs per location.

    Args:
        jobs (List[Dict]): A list of job postings.
    """
    # Get total count
    total_jobs = len(jobs)
    print(f"Total number of jobs: {total_jobs}")
    
    dept_counts = {}
    location_counts = {}
    
    for job in jobs:
        dept = job['dept']
        location = job['location']
        
        dept_counts[dept] = dept_counts.get(dept, 0) + 1
        location_counts[location] = location_counts.get(location, 0) + 1

    # Print department results
    print("\nJobs per department:")
    for dept, count in dept_counts.items():
        print(f"{dept}: {count}")
    
    # Print location results
    print("\nJobs per location:")
    for location, count in location_counts.items():
        print(f"{location}: {count}")

    return total_jobs



total_jobs = analyze_jobs(jobs)
# Out:
# Total number of jobs: 82
#
# Jobs per department:
# Operations: 20
# Fulfillment Center: 1
# Fulfillment Centers: 1
# Rapid and Rural Logistics (R2L): 1
# Amazon Web Services: 1
# Workplace Design & Construction: 1
# Customer Engagement Technology: 5
# Central Flow - Central Ops: 1
# Data and Machine Learning: 1
# WWPS US Federal: 1
# US Federal Data and Machine Learning: 1
# Logistics for Good: 1
# People eXperience and Technology: 2
# Business Operations, Customer Logistics Security (CLS): 1
# Worldwide Operations: 2
# Global Tax Services: 1
# Trusted Order and Remediation Experiences: 1
# Amazon AI: 1
# Customer Service: 2
# Amazon Vendor Services: 2
# Amazon Music Search: 1
# Risk Management: 1
# Global Specialty Fulfillment: 1
# Amazon Transportation Service (ATS): 1
# Pharmacy Operations: 1
# Customer Fulfilment: 1
# People Experience and Technology (PXT): 1
# Inclusive Experience and Technology: 1
# Amazon Extra Large (AMXL): 1
# Customer Fulfillment: 1
# Amazon Transportation: 1
# Listing Services, Core Selling Partner Experience: 1
# Human Resources: 1
# Prime Air: 1
# GREF: 1
# Commerce: 1
# Customer Service Technology: 1
# Social Media: 1
# Ads Security: 1
# Disability and Leave Service Team: 1
# AWS Infrastructure Services: 3
# Alexa Shopping: 1
# Central Technology Organization: 1
# Alexa Audio: 1
# Integrated Projects Quality (IPQ): 1
# ProServe Variable WWPS: 1
# Delivery Experience Speed: 1
# Helper: 1
# : 5
#
# Jobs per location:
# Not specified: 43
# AMD2: 1
# Tracy, CA: 2
# Little Rock, AR: 1
# Columbus, OH: 1
# Seattle, WA or Arlington, VA: 1
# Tempe, AZ & Nashville, TN: 1
# US Federal: 1
# AR, LA, MS, AL, GA: 1
# SD, NE, KS, MO, IA: 1
# NV, AZ, CO, UT: 1
# Connecticut: 1
# Vacaville, CA: 1
# Kent, WA: 1
# Bellevue, WA: 2
# Tepotzotlan, MEX: 1
# Seattle, WA: 4
# San Francisco, CA: 2
# Thornton, CO: 1
# Nationwide: 1
# Victoria, TX: 1
# São João de Meriti - RJ: 1
# FAT2: 1
# Prague, Czech Republic (or remote from Romania, Poland, Slovakia, and Czech Republic): 1
# Bucharest: 1
# MI, IN: 1
# Aurora, CO: 1
# Ohio: 1
# 139 W Jericho Turnpike, Huntington Station, NY 11746, USA: 2
# 10355 S Carlisle St, Terre Haute, IN 47802, USA: 1
# 4400 S Washington Ave, Mason City, IA 50401, USA: 1
# 270 Richards St, Brooklyn, NY 11231, USA: 1
# 45 Lau Pkwy, Clayton, OH 45315, USA: 1
